# %% [markdown]
# # Python with PostgreSQL & PostGIS

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# u:\Lektionen\GitHub_Repositories\python_postgresql_postgis

# %% [markdown]
# ## Create database connection

# %%
# Set up database connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Create Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test database connection
with engine.connect() as connection:
    result = connection.execute(text('SELECT current_database()'))
    print(result.fetchone())

# Dispose the engine
engine.dispose()
# Out:
# ('osm_switzerland',)

# %% [markdown]
# ## List tables in database

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Open a connection
with engine.connect() as connection:

    # Execute the query
    result = connection.execute(text("""SELECT table_name
                                        FROM information_schema.tables
                                        WHERE table_schema = 'public';"""))
    
    # Fetch and print the results
    for row in result:
        print(row[0])

# Dispose the engine
engine.dispose()
# Out:
# planet_osm_point
# geography_columns
# geometry_columns
# spatial_ref_sys
# planet_osm_polygon
# raster_columns
# raster_overviews
# planet_osm_line
# municipalities_ch
# planet_osm_roads
# roads_zuerich_vertices_pgr
# strassenlaerm_tag
# roads_zuerich
# route

# %% [markdown]
# ## Show columns and data types of selected table

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Specify your table name
table_name = 'planet_osm_polygon'

# Query to get column information
query = f"""SELECT column_name, data_type 
        FROM information_schema.columns 
        WHERE table_name = '{table_name}'"""

# Execute the query and read the result into a DataFrame
df = pd.read_sql(query, engine)

# Dispose the engine
engine.dispose()

# Print the DataFrame
df
# Out:
#          column_name     data_type
# 0             osm_id        bigint
# 1             access          text
# 2     addr:housename          text
# 3        addr:street          text
# 4   addr:housenumber          text
# ..               ...           ...
# 68             width          text
# 69              wood          text
# 70           z_order       integer
# 71          way_area          real
# 72               way  USER-DEFINED
#
# [73 rows x 2 columns]

# %% [markdown]
# ## Query: Select buildings for which full address is available in defined zip code areas

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Define SQL query 
sql = """SELECT
                p.osm_id,
                p."addr:street",
                p."addr:housenumber",
                p."addr:city",
                p."addr:postcode",
                p.building,
                st_transform(p.way, 4326) AS geom
        FROM
                public.planet_osm_polygon AS p
        WHERE
                p."addr:street" IS NOT NULL
                AND p."addr:housenumber" IS NOT NULL
                AND p."addr:city" IS NOT NULL
                AND p."addr:postcode" IN ('8001', '8002')"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Dispose the engine
engine.dispose()

# Print the GeoDataFrame
gdf
# Out:
#          osm_id         addr:street addr:housenumber addr:city addr:postcode  \
# 0     370058962  Waffenplatzstrasse              71c    Zürich          8002
# 1     149868409       Gablerstrasse               51    Zürich          8002
# 2      93184519  Waffenplatzstrasse               71    Zürich          8002
# 3     370058961  Waffenplatzstrasse              71b    Zürich          8002
# 4     370058960  Waffenplatzstrasse              71a    Zürich          8002
# ...         ...                 ...              ...       ...           ...
# 2351   32951943  Steinhaldenstrasse               68    Zürich          8002
# 2352  370058964  Waffenplatzstrasse              73a    Zürich          8002
# 2353  370058963  Waffenplatzstrasse              71d    Zürich          8002
# 2354   32951935  Waffenplatzstrasse               73    Zürich          8002
# 2355   32960425  Waffenplatzstrasse               69    Zürich          8002
#
#          building                                               geom
# 0            roof  POLYGON ((8.52737 47.35806, 8.52737 47.358, 8....
# 1     residential  POLYGON ((8.52723 47.35836, 8.52727 47.35831, ...
# 2             yes  POLYGON ((8.52735 47.35822, 8.52741 47.35814, ...
# 3             yes  POLYGON ((8.52753 47.35827, 8.52757 47.35823, ...
# 4             yes  POLYGON ((8.52757 47.35805, 8.52759 47.35792, ...
# ...           ...                                                ...
# 2351   apartments  POLYGON ((8.52762 47.35759, 8.52762 47.35754, ...
# 2352          yes  POLYGON ((8.52753 47.35772, 8.52753 47.35767, ...
# 2353         roof  POLYGON ((8.5275 47.35791, 8.5275 47.35786, 8....
# 2354   apartments  POLYGON ((8.52712 47.35783, 8.52712 47.35772, ...
# 2355   apartments  POLYGON ((8.52712 47.35792, 8.52727 47.35792, ...
#
# [2356 rows x 7 columns]

# %% [markdown]
# ## Show selected features on map
#
# <span style="color: blue;">Note the popup field in the map, which has been added to provide additional information about buildings.</span>
#
# <span style="color: blue;">Example of alternative background maps (maptiles) are:</span>
# - <span style="color: blue;">EsriWorldImagery</span>
# - <span style="color: blue;">EsriWorldTopoMap</span>
# - <span style="color: blue;">EsriWorldGrayCanvas</span>
# - <span style="color: blue;">CartoDBDarkMatter</span>
# - <span style="color: blue;">CartoDBPositron</span>

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=15,
               tiles='EsriWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='geojson',
    weight=0.5,
    fill_color='greenyellow',
    fillOpacity=0.8,
    popup=folium.GeoJsonPopup(fields=['addr:street',
                                      'addr:housenumber',
                                      'addr:city',
                                      'addr:postcode',
                                      'building'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f69fd9e08c241ce8825b44c865c7ebba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f69fd9e08c241ce8825b44c865c7ebba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f69fd9e08c241ce8825b44c865c7ebba = L.map(
#                 &quot;map_f69fd9e08c241ce8825b44c865c7ebba&quot;,
#                 {
#                     center: [47.367133538958214, 8.537079643591959],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c40333b00712a501c3e1b5f8a3eabc41 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c40333b00712a501c3e1b5f8a3eabc41.addTo(map_f69fd9e08c241ce8825b44c865c7ebba);
#
#
#
#         function geo_json_050d411e898f2888af96b52376f4df57_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_050d411e898f2888af96b52376f4df57 = L.geoJson(null, {
#                 onEachFeature: geo_json_050d411e898f2888af96b52376f4df57_onEachFeature,
#
#                 weight: 0.5,
#                 fillColor: &quot;greenyellow&quot;,
#                 fillOpacity: 0.8,
#         });
#
#         function geo_json_050d411e898f2888af96b52376f4df57_add (data) {
#             geo_json_050d411e898f2888af96b52376f4df57
#                 .addData(data);
#         }
#             geo_json_050d411e898f2888af96b52376f4df57_add({&quot;bbox&quot;: [8.518005399999998, 47.35035730008685, 8.550548200000001, 47.3801704000803], &quot;features&quot;: [{&quot;bbox&quot;: [8.5273717, 47.357997400085175, 8.527441499999998, 47.35806630008515], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.5273717, 47.358064800085174], [8.527374999999997, 47.357997400085175], [8.527441499999998, 47.35799900008517], [8.5274382, 47.35806630008515], [8.5273717, 47.358064800085174]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;71c&quot;, &quot;addr:postcode&quot;: &quot;8002&quot;, &quot;addr:street&quot;: &quot;Waffenplatzstrasse&quot;, &quot;building&quot;: &quot;roof&quot;, &quot;osm_id&quot;: 370058962}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.527225099999999, 47.35830650008512, 8.527353499999998, 47.358391200085094], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.527225099999999, 47.35835910008509], [8.5272682, 47.35830650008512], [8.527353499999998, 47.3583386000851], [8.5273104, 47.358391200085094], [8.527225099999999, 47.35835910008509]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;51&quot;, &quot;addr:postcode&quot;: &quot;8002&quot;, &quot;addr:street&quot;: &quot;Gablerstrasse&quot;, &quot;building&quot;: &quot;residential&quot;, &quot;osm_id&quot;: 149868409}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5273525, 47.35814220008514, 8.5275873, 47.3582793000851], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.5273525, 47.358217400085124], [8.527409599999999, 47.35814220008514], [8.5275873, 47.35820410008512], [8.5275702, 47.35822660008513], [8.527534399999999, 47.35827390008512], [8.5275303, 47.3582793000851], [8.5273525, 47.358217400085124]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;71&quot;, &quot;addr:postcode&quot;: &quot;8002&quot;, &quot;addr:street&quot;: &quot;Waffenplatzstrasse&quot;, &quot;building&quot;: &quot;yes&quot;, &quot;osm_id&quot;: 93184519}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.527534399999999, 47.35822660008513, 8.5276221, 47.358301500085105], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.527534399999999, 47.35827390008512], [8.5275702, 47.35822660008513], [8.5276221, 47.35824480008513], [8.5276126, 47.358301500085105], [8.527534399999999, 47.35827390008512]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;addr:housenumber&quot;: &quot;71b&quot

# %% [markdown]
# ## Query: Select coffee stores in Switzerland

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)  

# Define SQL query
sql = """SELECT
            h.osm_id,
            h.shop,
            h.name,
            ST_Transform(h.way, 4326) AS geom
        FROM planet_osm_point h
        WHERE h.shop = 'coffee';"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Dispose the engine
engine.dispose()

# Print the GeoDataFrame
gdf
# Out:
#           osm_id    shop                               name  \
# 0    10275946038  coffee                       Quinta Coira
# 1     4929337494  coffee                          Badilatti
# 2     4929338163  coffee  Rocca & Zgraggen Gastro-Maschinen
# 3     2411403524  coffee            Goldcastle Tea & Coffee
# 4     2473998249  coffee                   Pappy John & Cie
# ..           ...     ...                                ...
# 103   5434020963  coffee                             Tchibo
# 104   5434020954  coffee                          Nespresso
# 105   5611649752  coffee      Pelluch GmbH Kaffeemaschienen
# 106   8909393062  coffee                          Moccaraba
# 107   3322977512  coffee                             Tchibo
#
#                          geom
# 0     POINT (9.53125 46.8485)
# 1     POINT (9.9654 46.59732)
# 2    POINT (9.96413 46.59663)
# 3    POINT (6.95454 47.07048)
# 4    POINT (6.65236 46.52688)
# ..                        ...
# 103  POINT (7.24634 47.13622)
# 104  POINT (7.24578 47.13613)
# 105  POINT (7.54718 47.54892)
# 106  POINT (7.59199 47.56274)
# 107  POINT (7.94814 47.55261)
#
# [108 rows x 4 columns]

# %% [markdown]
# ## Show selected features on map

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=9, 
               tiles='EsriWorldTopoMap')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
    popup=folium.GeoJsonPopup(fields=['name', 'shop'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65481500376f05741f94b6fa896b5dc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65481500376f05741f94b6fa896b5dc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65481500376f05741f94b6fa896b5dc5 = L.map(
#                 &quot;map_65481500376f05741f94b6fa896b5dc5&quot;,
#                 {
#                     center: [47.07191618162387, 8.016506228703703],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f214fec1d39ea076389dffde7576f57e = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Esri, DeLorme, NAVTEQ, TomTom, Intermap, iPC, USGS, FAO, NPS, NRCAN, GeoBase, Kadaster NL, Ordnance Survey, Esri Japan, METI, Esri China (Hong Kong), and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f214fec1d39ea076389dffde7576f57e.addTo(map_65481500376f05741f94b6fa896b5dc5);
#
#
#
#         function geo_json_8cbffc69a38251d78bd573342bca7af8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8cbffc69a38251d78bd573342bca7af8 = L.geoJson(null, {
#                 onEachFeature: geo_json_8cbffc69a38251d78bd573342bca7af8_onEachFeature,
#
#         });
#
#         function geo_json_8cbffc69a38251d78bd573342bca7af8_add (data) {
#             geo_json_8cbffc69a38251d78bd573342bca7af8
#                 .addData(data);
#         }
#             geo_json_8cbffc69a38251d78bd573342bca7af8_add({&quot;bbox&quot;: [6.0723283, 46.003245800342015, 9.9654012, 47.562737800039514], &quot;features&quot;: [{&quot;bbox&quot;: [9.531246000000001, 46.848496000191844, 9.531246000000001, 46.848496000191844], &quot;geometry&quot;: {&quot;coordinates&quot;: [9.531246000000001, 46.848496000191844], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Quinta Coira&quot;, &quot;osm_id&quot;: 10275946038, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [9.9654012, 46.59732160024026, 9.9654012, 46.59732160024026], &quot;geometry&quot;: {&quot;coordinates&quot;: [9.9654012, 46.59732160024026], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Badilatti&quot;, &quot;osm_id&quot;: 4929337494, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [9.9641257, 46.59663400024037, 9.9641257, 46.59663400024037], &quot;geometry&quot;: {&quot;coordinates&quot;: [9.9641257, 46.59663400024037], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Rocca \u0026 Zgraggen Gastro-Maschinen&quot;, &quot;osm_id&quot;: 4929338163, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [6.9545362, 47.070475100146695, 6.9545362, 47.070475100146695], &quot;geometry&quot;: {&quot;coordinates&quot;: [6.9545362, 47.070475100146695], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Goldcastle Tea \u0026 Coffee&quot;, &quot;osm_id&quot;: 2411403524, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [6.6523587, 46.52688200025328, 6.6523587, 46.52688200025328], &quot;geometry&quot;: {&quot;coordinates&quot;: [6.6523587, 46.52688200025328], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Pappy John \u0026 Cie&quot;, &quot;osm_id&quot;: 2473998249, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [6.628509799999999, 46.522810300254015, 6.628509799999999, 46.522810300254015], &quot;geometry&quot;: {&quot;coordinates&quot;: [6.628509799999999, 46.522810300254015], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Bel-Air Coffee&quot;, &quot;osm_id&quot;: 9780147859, &quot;shop&quot;: &quot;coffee&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [6.629754899999999, 46.51805860025489, 6.629754899999999, 46.51805860025489], &quot;geometry&quot;: {&quot;coordinates&quot;: [6.629754899999999, 46.51805860025489], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&q

# %% [markdown]
# ## Query: Select all supermarkets in a distance of 1000m around the central station in the city of Winterthur.
#
# <span style="color: blue;">For each supermarket, the distance to the central station in meters is calculated and stored as new column 'distance_meters'.</span>
#
# <span style="color: blue;">In addition, a popup field was added to the map, allowing users to view detailed information about each selected feature when they click on it.</span>
#
# <span style="color: blue;">Note that WGS84 (World Geodetic System 1984) coordinates in ST_MakePoint(LON, LAT) can be derived from:</span>
#
# - <span style="color: blue;">https://tools.retorte.ch/map</span>

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)  

# Define SQL query
sql = """SELECT
            p.osm_id,
            p.shop,
            p.name,
            ST_Distance(
                ST_Transform(p.way, 4326)::geography,
                -- Central station coordinates
                ST_SetSRID(ST_MakePoint(8.72397, 47.50031), 4326)::geography
            ) AS distance_meters,
            ST_TRANSFORM(p.way, 4326) AS geom
        FROM
            planet_osm_point AS p
        WHERE
            p.shop = 'supermarket'
            AND ST_DWithin(
                ST_Transform(p.way, 4326)::geography,
                -- Central station coordinates
                ST_SetSRID(ST_MakePoint(8.72397, 47.50031), 4326)::geography,
                1000
            )
        ORDER BY distance_meters;"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Dispose the engine
engine.dispose()

# Print the GeoDataFrame
gdf
# Out:
#        osm_id         shop                          name  distance_meters  \
# 0   706203439  supermarket                          Coop       159.883419
# 1  4109460421  supermarket                     Asia Shop       162.391281
# 2  3831772784  supermarket                        Migros       247.578208
# 3  7380954145  supermarket                      Alnatura       256.838011
# 4  4095400190  supermarket                          ALDI       274.275393
# 5  4125136758  supermarket  Tandoor Indischer Supermarkt       290.212664
# 6  4095400136  supermarket                        Denner       316.354037
# 7   709022324  supermarket               Claro Weltladen       441.129317
# 8  4058248551  supermarket                        Migros       600.117307
# 9  3441033104  supermarket                L'Ultimo Bacio       680.202961
#
#                        geom
# 0  POINT (8.72594 47.50085)
# 1  POINT (8.72208 47.50101)
# 2  POINT (8.72115 47.49916)
# 3  POINT (8.72074 47.49958)
# 4   POINT (8.72476 47.4979)
# 5  POINT (8.72017 47.50073)
# 6  POINT (8.72036 47.49886)
# 7  POINT (8.72912 47.49842)
# 8  POINT (8.73193 47.50012)
# 9  POINT (8.73299 47.49999)

# %% [markdown]
# ## Show selected features on map

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='ESRIWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
    popup=folium.GeoJsonPopup(fields=['name', 'distance_meters'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8556e8c29dc4d52ceabb28411c94956f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8556e8c29dc4d52ceabb28411c94956f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8556e8c29dc4d52ceabb28411c94956f = L.map(
#                 &quot;map_8556e8c29dc4d52ceabb28411c94956f&quot;,
#                 {
#                     center: [47.49966227005374, 8.72492239],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6d93db1359dfacb6a617c7ccde70bef = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f6d93db1359dfacb6a617c7ccde70bef.addTo(map_8556e8c29dc4d52ceabb28411c94956f);
#
#
#
#         function geo_json_d18a6033f11acda6f5c4e87013013874_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d18a6033f11acda6f5c4e87013013874 = L.geoJson(null, {
#                 onEachFeature: geo_json_d18a6033f11acda6f5c4e87013013874_onEachFeature,
#
#         });
#
#         function geo_json_d18a6033f11acda6f5c4e87013013874_add (data) {
#             geo_json_d18a6033f11acda6f5c4e87013013874
#                 .addData(data);
#         }
#             geo_json_d18a6033f11acda6f5c4e87013013874_add({&quot;bbox&quot;: [8.7201688, 47.49790130005414, 8.732985899999997, 47.50100990005341], &quot;features&quot;: [{&quot;bbox&quot;: [8.725937799999999, 47.500848300053455, 8.725937799999999, 47.500848300053455], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.725937799999999, 47.500848300053455], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 159.88341889, &quot;name&quot;: &quot;Coop&quot;, &quot;osm_id&quot;: 706203439, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.722078199999999, 47.50100990005341, 8.722078199999999, 47.50100990005341], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.722078199999999, 47.50100990005341], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 162.39128099, &quot;name&quot;: &quot;Asia Shop&quot;, &quot;osm_id&quot;: 4109460421, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.721153199999998, 47.499163300053844, 8.721153199999998, 47.499163300053844], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.721153199999998, 47.499163300053844], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 247.57820784, &quot;name&quot;: &quot;Migros&quot;, &quot;osm_id&quot;: 3831772784, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7207353, 47.49958100005376, 8.7207353, 47.49958100005376], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7207353, 47.49958100005376], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 256.83801124, &quot;name&quot;: &quot;Alnatura&quot;, &quot;osm_id&quot;: 7380954145, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7247563, 47.49790130005414, 8.7247563, 47.49790130005414], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7247563, 47.49790130005414], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 274.27539294, &quot;name&quot;: &quot;ALDI&quot;, &quot;osm_id&quot;: 4095400190, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7201688, 47.50073210005348, 8.7201688, 47.50073210005348], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7201688, 47.50073210005348], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 290.21266361, &quot;name&quot;: &quot;Tandoor Indischer Supermarkt&quot;, &quot;osm_id&quot;: 4125136758, &quot;shop&quot;: &quot;supermarket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7203601, 47.49885680005391, 8.7203601, 47.49

# %% [markdown]
# ## Query: Select all roads classified as 'primary' in Switzerland and create 5000m buffers around these roads

# %%
# Create SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Define SQL query (major roads)
sql = """-- Create buffers around major roads and combine these buffers to one single buffer
        SELECT 
            1 as group_id,
            ST_TRANSFORM(ST_UNION(ST_Buffer(p.way::geometry, 5000)), 4326) AS geom
        FROM public.planet_osm_roads AS p
        WHERE
            --highway IN ('motorway', 'trunk', 'primary')
            highway IN ('motorway');"""

# Query the database and store the result in a GeoDataFrame
gdf = gpd.GeoDataFrame.from_postgis(sql, engine, geom_col='geom')

# Dispose the engine
engine.dispose()

# %% [markdown]
# ## Show selected features on map

# %%
# Ensure the GeoDataFrame has the correct projection (EPSG:4326)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Calculate the mean longitude and latitude for the map center
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialize the map
m = folium.Map(location=[lat, lon], 
               zoom_start=9, 
               tiles='EsriWorldTopoMap')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_734e780ecd0a3f23e1e075d8297501f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_734e780ecd0a3f23e1e075d8297501f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_734e780ecd0a3f23e1e075d8297501f4 = L.map(
#                 &quot;map_734e780ecd0a3f23e1e075d8297501f4&quot;,
#                 {
#                     center: [46.94541936813398, 7.97860798346879],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30779bdef17301ea02660c0319de79e7 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Esri, DeLorme, NAVTEQ, TomTom, Intermap, iPC, USGS, FAO, NPS, NRCAN, GeoBase, Kadaster NL, Ordnance Survey, Esri Japan, METI, Esri China (Hong Kong), and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30779bdef17301ea02660c0319de79e7.addTo(map_734e780ecd0a3f23e1e075d8297501f4);
#
#
#
#         function geo_json_1794b67faabd86cc4969bde13db80853_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1794b67faabd86cc4969bde13db80853 = L.geoJson(null, {
#                 onEachFeature: geo_json_1794b67faabd86cc4969bde13db80853_onEachFeature,
#
#         });
#
#         function geo_json_1794b67faabd86cc4969bde13db80853_add (data) {
#             geo_json_1794b67faabd86cc4969bde13db80853
#                 .addData(data);
#         }
#             geo_json_1794b67faabd86cc4969bde13db80853_add({&quot;bbox&quot;: [6.030430804639078, 45.807419371543126, 9.71482645723699, 47.69194984752157], &quot;features&quot;: [{&quot;bbox&quot;: [6.030430804639078, 45.807419371543126, 9.71482645723699, 47.69194984752157], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[6.055981956950482, 46.13032963015194], [6.0555830606905, 46.1311873050739], [6.054959378164361, 46.13251781026045], [6.054417746828305, 46.13365901418638], [6.0544113763545555, 46.13366908508567], [6.05396232256605, 46.13440449084966], [6.0539236225660495, 46.13447020488303], [6.051411756667229, 46.14031794969997], [6.050594550000278, 46.146392238680825], [6.051220131183831, 46.150568576013235], [6.051126766572795, 46.15147324571762], [6.051993114692331, 46.156250259067754], [6.051521069752016, 46.156676420793026], [6.051090669752016, 46.157075655852054], [6.049833632630947, 46.15830244153293], [6.049431632630947, 46.15871557208605], [6.04825579769086, 46.1599897002148], [6.047883197690861, 46.160415925039906], [6.046801877837199, 46.16172329182101], [6.046459577837198, 46.16216140972245], [6.045470885181818, 46.16350350493859], [6.0451595851818185, 46.1639526148459], [6.044267338322533, 46.1653238428504], [6.043987738322533, 46.1657828437408], [6.043186521690135, 46.167193098461375], [6.042939521690134, 46.16766098931386], [6.042244274033195, 46.16908355787244], [6.042030174033196, 46.16955913792125], [6.041433290072821, 46.17100749264633], [6.041252690072819, 46.17148966110979], [6.040488036062538, 46.17353374432201], [6.0403436646145146, 46.173930399298854], [6.04019265861042, 46.17435710007425], [6.040065001140993, 46.174531669241084], [6.039581069647677, 46.17521399446595], [6.039391969647676, 46.17548906133322], [6.03928873243824, 46.17564027706466], [6.0390049324382415, 46.176058877674], [6.038107341758265, 46.1774730592245], [6.0379651417582645, 46.177713110748336], [6.037801369294259, 46.17799345224132], [6.03759256929426, 46.17835592819468], [6.0371372711573255, 46.17918010553179], [6.037006671157325, 46.17942695355741], [6.036787376370459, 46.179850920695586], [6.036683076370458, 46.18005725924932], [6.036481755544067, 46.18063060837161], [6.036152241917204, 46.18117475917481], [6.036175664856088, 46.18111669583075], [6.035773968821134, 46.18202953169089], [6.035691350037248, 46.18222815818081], [6.035640434975344, 46.18235037348115], [6.035549070559656, 46.18269285663817], [6.03537343226235, 46.18301921075695], [6.035209032262349, 46.18344967300118], [6.034763262665065, 46.18472516781381], [6.034610262665064, 46.1852072263364], [6.034378873474611, 46.18598330452064], [6.034300573474611, 46.18626393462838], [6.034052265296244, 46.187236580750266], [6.033969865296243, 46.18759221261288], [6.03379826277696, 46.188400607648234], [6.03373486277696, 46.188729232258694], [6.033637632078183, 46.1892691709255], [6.033586632078183, 46.189574090765774], [6.033421471109975, 46.190759989630855], [6.033381771109974, 46.191116405132284], [6.033317686701877, 46.1917858957241], [6.033285686701877, 46.19218550823681], [6.03323895021827, 46.19305215756255], [6.032954228866342, 46.19365955918393], [6.032864528866343, 46.19386299278216], [6.032715719279253, 46.19420760801292], [6.032628919279253, 46.19441294063751], [6.032282307846692, 46.1952791305248], [6.032198507846691, 46.195500962275034], [6.031887995194151, 46.196374359203475], [6.031813195194153, 46.19659868774626], [6.0317443571604645, 46.196966998985886], [6.031585183832534, 46.19732165781969

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2024-10-01 18:46:29
# Python Version: 3.11.9
# -----------------------------------
